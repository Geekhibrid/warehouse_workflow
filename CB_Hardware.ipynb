# %%
from PIL import Image

# %%
from PIL import Image
catIm = Image.open('Dashboard.png')  #Open the cat image
croppedIm = catIm.crop((50,50,175,175))
croppedIm.save('croppedCat.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[448], line 2
#       1 from PIL import Image
# ----> 2 catIm = Image.open('Dashboard.png')  #Open the cat image
#       3 croppedIm = catIm.crop((50,50,175,175))
#       4 croppedIm.save('croppedCat.png')
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3247, in open(fp, mode, formats)
#    3244     filename = fp
#    3246 if filename:
# -> 3247     fp = builtins.open(filename, "rb")
#    3248     exclusive_fp = True
#    3250 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dashboard.png'

# %%
import pandas as pd

# %%
accounts_data = pd.read_csv('Accounts.csv')
meta_data = pd.read_csv('Metadata.csv')
product_data = pd.read_csv('Products.csv')
sales_pipeline = pd.read_csv('Sales_Pipeline.csv')
sales_team = pd.read_csv('Sales_Teams.csv')

# %%
import numpy as np

# %% [markdown]
# ## Observe each table and analyze the columns that we need to keep
# ## observe the columns for missing or null values

# %%
accounts_data
## Accounts table have 0 null or missing values
# Out:
#              account         sector  year_established  revenue  employees  \
# 0   Acme Corporation      technolgy              1996  1100.04       2822
# 1         Betasoloin        medical              1999   251.41        495
# 2           Betatech        medical              1986   647.18       1185
# 3         Bioholding        medical              2012   587.34       1356
# 4            Bioplex        medical              1991   326.82       1016
# ..               ...            ...               ...      ...        ...
# 80        Zathunicon         retail              2010    71.12        144
# 81    Zencorporation      technolgy              2011    40.79        142
# 82            Zoomit  entertainment              1992   324.19        978
# 83           Zotware       software              1979  4478.47      13809
# 84          Zumgoity        medical              1984   441.08       1210
#
#    office_location
# 0    United States
# 1    United States
# ...

# %%
meta_data
# Metadata has 0 null or missing values
# Out:
#              Table             Field  \
# 0         accounts           account
# 1         accounts            sector
# 2         accounts  year_established
# 3         accounts           revenue
# 4         accounts         employees
# 5         accounts   office_location
# 6         accounts     subsidiary_of
# 7         products           product
# 8         products            series
# 9         products       sales_price
# 10     sales_teams       sales_agent
# 11     sales_teams           manager
# 12     sales_teams   regional_office
# 13  sales_pipeline    opportunity_id
# 14  sales_pipeline       sales_agent
# 15  sales_pipeline           product
# 16  sales_pipeline           account
# 17  sales_pipeline        deal_stage
# 18  sales_pipeline       engage_date
# 19  sales_pipeline        close_date
# 20  sales_pipeline       close_value
#
#                                           Description
# 0                                        Company name
# ...

# %%
product_data
# Table has 0 null or missing values
# Out:
#           product series  sales_price
# 0       GTX Basic    GTX          550
# 1         GTX Pro    GTX         4821
# 2      MG Special     MG           55
# 3     MG Advanced     MG         3393
# 4    GTX Plus Pro    GTX         5482
# 5  GTX Plus Basic    GTX         1096
# 6         GTK 500    GTK        26768

# %% [markdown]
# ## Eliminate Unecessary Columns

# %%
sales_pipeline.drop(columns=['account'], inplace = True)

# %%
sales_pipeline
## We rid of the accounts solumn to isolate the information soleley about the agents, products, deal stage and close
# Out:
#      opportunity_id        sales_agent         product   deal_stage  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic          Won
# 1          Z063OYW0    Darcel Schlecht          GTXPro          Won
# 2          EC4QE1BX    Darcel Schlecht      MG Special          Won
# 3          MV1LWRNH        Moses Frase       GTX Basic          Won
# 4          PE84CX4O          Zane Levy       GTX Basic          Won
# ...             ...                ...             ...          ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced  Prospecting
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced  Prospecting
#
#       close_value
# 0          1054.0
# 1          4514.0
# 2            50.0
# 3           588.0
# 4           517.0
# ...           ...
# ...

# %%
sales_pipeline.drop(columns=['engage_date', 'close_date'], inplace = True)

# %%
sales_team
## we rid of the engage date and close date columns because we have updated dates that we need to add to the table.
# Out:
#            sales_agent           manager regional_office
# 0        Anna Snelling  Dustin Brinkmann         Central
# 1       Cecily Lampkin  Dustin Brinkmann         Central
# 2    Versie Hillebrand  Dustin Brinkmann         Central
# 3      Lajuana Vencill  Dustin Brinkmann         Central
# 4          Moses Frase  Dustin Brinkmann         Central
# 5   Jonathan Berthelot     Melvin Marxen         Central
# 6    Marty Freudenburg     Melvin Marxen         Central
# 7     Gladys Colclough     Melvin Marxen         Central
# 8      Niesha Huffines     Melvin Marxen         Central
# 9      Darcel Schlecht     Melvin Marxen         Central
# 10       Mei-Mei Johns     Melvin Marxen         Central
# 11    Violet Mclelland        Cara Losch            East
# 12       Corliss Cosme        Cara Losch            East
# 13  Rosie Papadopoulos        Cara Losch            East
# 14       Garret Kinder        Cara Losch            East
# ...

# %% [markdown]
# ### Now we will concatenate the tables together after dropping the necessary columns

# %%
cb_hardware = pd.concat([sales_pipeline, sales_team], ignore_index = True)

# %%
cb_hardware
# Out:
#      opportunity_id      sales_agent         product deal_stage  close_value  \
# 0          1C1I7A6R      Moses Frase  GTX Plus Basic        Won       1054.0
# 1          Z063OYW0  Darcel Schlecht          GTXPro        Won       4514.0
# 2          EC4QE1BX  Darcel Schlecht      MG Special        Won         50.0
# 3          MV1LWRNH      Moses Frase       GTX Basic        Won        588.0
# 4          PE84CX4O        Zane Levy       GTX Basic        Won        517.0
# ...             ...              ...             ...        ...          ...
# 8830            NaN  Kary Hendrixson             NaN        NaN          NaN
# 8831            NaN    Kami Bicknell             NaN        NaN          NaN
# 8832            NaN        Zane Levy             NaN        NaN          NaN
# 8833            NaN  Maureen Marcano             NaN        NaN          NaN
# 8834            NaN         Carl Lin             NaN        NaN          NaN
#
#             manager regional_office
# ...

# %%
cb_hardware.drop(columns=['regional_office', 'manager'], inplace = True)

# %%
cb_hardware
# Out:
#              account  close_value  manager         product regional_office  \
# 0             unkown       1054.0  unknown  GTX Plus Basic         unknown
# 1             unkown       4514.0  unknown          GTXPro         unknown
# 2             unkown         50.0  unknown      MG Special         unknown
# 3             unkown        588.0  unknown       GTX Basic         unknown
# 4             unkown        517.0  unknown       GTX Basic         unknown
# ...              ...          ...      ...             ...             ...
# 8922      Zathunicon          0.0  unknown         unknown         unknown
# 8923  Zencorporation          0.0  unknown         unknown         unknown
# 8924          Zoomit          0.0  unknown         unknown         unknown
# 8925         Zotware          0.0  unknown         unknown         unknown
# 8926        Zumgoity          0.0  unknown         unknown         unknown
#
#           sales_agent
# 0         Moses Frase
# ...

# %%
sales_pipeline
# Out:
#      opportunity_id        sales_agent         product   deal_stage  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic          Won
# 1          Z063OYW0    Darcel Schlecht          GTXPro          Won
# 2          EC4QE1BX    Darcel Schlecht      MG Special          Won
# 3          MV1LWRNH        Moses Frase       GTX Basic          Won
# 4          PE84CX4O          Zane Levy       GTX Basic          Won
# ...             ...                ...             ...          ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced  Prospecting
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced  Prospecting
#
#       close_value
# 0          1054.0
# 1          4514.0
# 2            50.0
# 3           588.0
# 4           517.0
# ...           ...
# ...

# %%
cb_hardware
# Out:
#      opportunity_id      sales_agent         product deal_stage  close_value
# 0          1C1I7A6R      Moses Frase  GTX Plus Basic        Won       1054.0
# 1          Z063OYW0  Darcel Schlecht          GTXPro        Won       4514.0
# 2          EC4QE1BX  Darcel Schlecht      MG Special        Won         50.0
# 3          MV1LWRNH      Moses Frase       GTX Basic        Won        588.0
# 4          PE84CX4O        Zane Levy       GTX Basic        Won        517.0
# ...             ...              ...             ...        ...          ...
# 8830            NaN  Kary Hendrixson             NaN        NaN          NaN
# 8831            NaN    Kami Bicknell             NaN        NaN          NaN
# 8832            NaN        Zane Levy             NaN        NaN          NaN
# 8833            NaN  Maureen Marcano             NaN        NaN          NaN
# 8834            NaN         Carl Lin             NaN        NaN          NaN
#
# [8835 rows x 5 columns]

# %%
cb_hardware = pd.concat([sales_pipeline, sales_team, product_data, accounts_data], ignore_index = True)

# %%
cb_hardware
## There are still plenty of missing values that we need to fix since joining more tables.
# Out:
#      opportunity_id      sales_agent         product deal_stage  close_value  \
# 0          1C1I7A6R      Moses Frase  GTX Plus Basic        Won       1054.0
# 1          Z063OYW0  Darcel Schlecht          GTXPro        Won       4514.0
# 2          EC4QE1BX  Darcel Schlecht      MG Special        Won         50.0
# 3          MV1LWRNH      Moses Frase       GTX Basic        Won        588.0
# 4          PE84CX4O        Zane Levy       GTX Basic        Won        517.0
# ...             ...              ...             ...        ...          ...
# 8922            NaN              NaN             NaN        NaN          NaN
# 8923            NaN              NaN             NaN        NaN          NaN
# 8924            NaN              NaN             NaN        NaN          NaN
# 8925            NaN              NaN             NaN        NaN          NaN
# 8926            NaN              NaN             NaN        NaN          NaN
#
# ...

# %%
cb_hardware.drop(columns=['sector', 'year_established', 'revenue', 'office_location'], inplace = True)

# %%
cb_hardware
# Out:
#      opportunity_id      sales_agent         product deal_stage  close_value  \
# 0          1C1I7A6R      Moses Frase  GTX Plus Basic        Won       1054.0
# 1          Z063OYW0  Darcel Schlecht          GTXPro        Won       4514.0
# 2          EC4QE1BX  Darcel Schlecht      MG Special        Won         50.0
# 3          MV1LWRNH      Moses Frase       GTX Basic        Won        588.0
# 4          PE84CX4O        Zane Levy       GTX Basic        Won        517.0
# ...             ...              ...             ...        ...          ...
# 8922            NaN              NaN             NaN        NaN          NaN
# 8923            NaN              NaN             NaN        NaN          NaN
# 8924            NaN              NaN             NaN        NaN          NaN
# 8925            NaN              NaN             NaN        NaN          NaN
# 8926            NaN              NaN             NaN        NaN          NaN
#
# ...

# %% [markdown]
# ### Fill in missing values using the Fillna method

# %%
cb_hardware.fillna({
    'Opportunity_id': 0,
    'sales_agent': 'unknown',
    'product': 'unknown',
    'deal_stage': 'unknown',
    'close_value': 0,
    'manager': 'unknown',
    'regional_office': 'unknown',
    'series': 'unknown',
    'sales_price': 0,
    'account': 'unkown',
    'employees': 0
}, inplace=True)

# %%
cb_hardware
## We made sure that the string values were labeled, "unknown" and the ints as "0"
# Out:
#      opportunity_id      sales_agent         product deal_stage  close_value  \
# 0          1C1I7A6R      Moses Frase  GTX Plus Basic        Won       1054.0
# 1          Z063OYW0  Darcel Schlecht          GTXPro        Won       4514.0
# 2          EC4QE1BX  Darcel Schlecht      MG Special        Won         50.0
# 3          MV1LWRNH      Moses Frase       GTX Basic        Won        588.0
# 4          PE84CX4O        Zane Levy       GTX Basic        Won        517.0
# ...             ...              ...             ...        ...          ...
# 8922            NaN          unknown         unknown    unknown          0.0
# 8923            NaN          unknown         unknown    unknown          0.0
# 8924            NaN          unknown         unknown    unknown          0.0
# 8925            NaN          unknown         unknown    unknown          0.0
# 8926            NaN          unknown         unknown    unknown          0.0
#
# ...

# %%
cb_hardware.drop(columns=['employees', 'sales_price'], inplace = True)

# %%
cb_hardware

## Now we're going to drop two more columns, employees and sales_price, to narrow our focus even more.
# Out:
#      opportunity_id      sales_agent         product deal_stage  close_value  \
# 0          1C1I7A6R      Moses Frase  GTX Plus Basic        Won       1054.0
# 1          Z063OYW0  Darcel Schlecht          GTXPro        Won       4514.0
# 2          EC4QE1BX  Darcel Schlecht      MG Special        Won         50.0
# 3          MV1LWRNH      Moses Frase       GTX Basic        Won        588.0
# 4          PE84CX4O        Zane Levy       GTX Basic        Won        517.0
# ...             ...              ...             ...        ...          ...
# 8922            NaN          unknown         unknown    unknown          0.0
# 8923            NaN          unknown         unknown    unknown          0.0
# 8924            NaN          unknown         unknown    unknown          0.0
# 8925            NaN          unknown         unknown    unknown          0.0
# 8926            NaN          unknown         unknown    unknown          0.0
#
# ...

# %%
cb_hardware = cb_hardware[sorted(cb_hardware.columns)]
cb_hardware

## We wanted to sort the columns to see the actual values of the chsen columns
# Out:
#              account  close_value deal_stage  manager opportunity_id  \
# 0             unkown       1054.0        Won  unknown       1C1I7A6R
# 1             unkown       4514.0        Won  unknown       Z063OYW0
# 2             unkown         50.0        Won  unknown       EC4QE1BX
# 3             unkown        588.0        Won  unknown       MV1LWRNH
# 4             unkown        517.0        Won  unknown       PE84CX4O
# ...              ...          ...        ...      ...            ...
# 8922      Zathunicon          0.0    unknown  unknown            NaN
# 8923  Zencorporation          0.0    unknown  unknown            NaN
# 8924          Zoomit          0.0    unknown  unknown            NaN
# 8925         Zotware          0.0    unknown  unknown            NaN
# 8926        Zumgoity          0.0    unknown  unknown            NaN
#
#              product regional_office      sales_agent   series
# 0     GTX Plus Basic         unknown      Moses Frase  unknown
# ...

# %%
cb_hardware.drop(columns=['opportunity_id', 'series', 'deal_stage'], inplace = True)

# %%
cb_hardware
## We took away three more columns, opportuinty id, series and deal stage. 
## we wanted to focus on more important columns such as the chosen ones below since they meet our criteria.
## As you can see, we brought the account column back into the dataset since it turned out to be a vaulable mtric to the data
# Out:
#              account  close_value  manager         product regional_office  \
# 0             unkown       1054.0  unknown  GTX Plus Basic         unknown
# 1             unkown       4514.0  unknown          GTXPro         unknown
# 2             unkown         50.0  unknown      MG Special         unknown
# 3             unkown        588.0  unknown       GTX Basic         unknown
# 4             unkown        517.0  unknown       GTX Basic         unknown
# ...              ...          ...      ...             ...             ...
# 8922      Zathunicon          0.0  unknown         unknown         unknown
# 8923  Zencorporation          0.0  unknown         unknown         unknown
# 8924          Zoomit          0.0  unknown         unknown         unknown
# 8925         Zotware          0.0  unknown         unknown         unknown
# 8926        Zumgoity          0.0  unknown         unknown         unknown
#
#           sales_agent
# 0         Moses Frase
# ...

# %%
cb_hardware.to_csv('output.csv', index=False)

## now that we have what we need from this project, we are going to export the file for further analysis.
